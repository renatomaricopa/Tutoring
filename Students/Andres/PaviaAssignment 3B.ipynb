# %% [markdown]
# ## DSS 615 - Fall 2021 Assignments
# ## Assignment-3B
# Modified: 8/21/2021
#
# Submit entire notebook as one file. Note there are several exercises in this assignment. **Remember to add your last name to the file name.**

# %% [markdown]
# Student: Andres Pavia

# %% [markdown]
# # Ex  6.7 Character Counts
# See the text book for the details of the exercise.
#
# **NOTE:** The challenge part of the assignment is required.
#
# Part A requirements:
# * Use the `text` variable already provided instead of getting input from the user. (Feel free to add additional cells if you want to try adding the input function. I won't grade it but will provide feedback.)
# * Create a **list** called `characters` of just the lower case letters and punctuation in the list, no spaces. It will look something like this: [h, o, w, m, u...]
# * Create a **dictionary** called `character_counts` to summarize the number of occurrences of each letter. You'll probably iterate through the `characters` variable and add each character to the dictionary with the extend method.
# * Ignore case, ignore blanks, assume no punctuation entered
# * Display a two-column table of letters and counts with letters in sorted order
# * Iterate through the sentence to create the dictionary. DO NOT use a count() function.
# * Print out the results in sorted order so it looks like this:
# ![image.png](attachment:image.png)

# %%
# Part A:
text = ('How much wood could a woodchuck chuck'
        'If a woodchuck could chuck wood?'
        'As much wood as a woodchuck could chuck,'
        'If a woodchuck could chuck wood.')
# Your code follows
characters = list("".join(text.strip().lower().split()))
character_counts = {}
for char in characters:
    if char in character_counts:
        character_counts[char] += 1
    else: character_counts[char] = 1
sorted_cc_list = sorted(character_counts.items())
print(f'CHARACTER    COUNT')
for char, freq in sorted_cc_list:
    print(f'{char:<13}{freq:<5}')
# Out:
# CHARACTER    COUNT
# ,            1
# .            1
# ?            1
# a            6
# c            22
# d            12
# f            2
# h            11
# i            2
# k            8
# l            4
# m            2
# o            21
# s            2
# u            14
# w            9

# %%
print('character\t count')
print(f'{characters[0:7]}')
# Out:
# character	 count
# [',', '.', 'a', 'c', 'd', 'f', 'h']

# %% [markdown]
# Part B requirement:
# * Convert the dictionary keys to a set called `unique_letters`
# * Use a **set comprehension** to create a new set called `letters` which includes only the lower case letters from 'a' to 'z'.
# * Use a **set operation** to compare the two sets and find which letters of the alphabet were **not** in the original string. Output that result. It should look something like this.
# ![image.png](attachment:image.png)

# %%
# Part B:

# %% [markdown]
# # Ex. 6.9 Dictionary Manipulations
# See book for specifics. Note, the dictionary is already given. Be sure to run the cell. A code cell for each parts is given. Add your code to the appropriate cells.

# %%
tlds = {'Canada': 'ca', 'United States':'us', 'Mexico':'mx'}

# %% [markdown]
# ### a) Check whether dictionary contains the key 'Canada'. Print the appropriate Boolean in a statement.

# %%
if 'Canada' in tlds:
    print('Canada is in tlds')
else:
    print('canada is not in dictionary')
# Out:
# Canada is in tlds

# %% [markdown]
# ### b) Check whether dictionary contains the key 'France'. Print the appropriate Boolean in a statement.

# %%
if 'France' in tlds:
    print('France is in tlds')
else:
    print('France is not in tlds')
# Out:
# France is not in tlds

# %% [markdown]
# ### c) Iterate through the key-value pairs and disply them in a two-column format.
# ![image.png](attachment:image.png)

# %%
for key, value in tlds.items():
    print(f'{key:20}{value}')
# Out:
# Canada              ca
# United States       us
# Mexico              mx

# %% [markdown]
# ### d) Add the key-value pair 'Sweden' and 'sw' (which is incorrect), display tlds to show it was added
# ![image.png](attachment:image.png)

# %% [markdown]
# ### e) Update the value for the key 'Sweden' to 'se', display tlds to show it was changed
# ![image.png](attachment:image.png)

# %% [markdown]
# ### f) Use a dictionary comprehension to reverse the keys and values.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### g) With the result of part (f), use a dictionary comprehension to convert the country names to all uppercase letters.
# ![image.png](attachment:image.png)

# %% [markdown]
# # Ex. 6.10 Set Manipulations
#
# See the book for the details. Use the three code cells below for your code.
#
# **Most common reason for deductions**
# * Not showing all of the possible set comparisons. There are six comparison operators.
# * Not showing all of the set operations. There will be five. (One of them you do twice in different directions.

# %%
# Part 0 -- create the two sets

# %%
# Part a -- compare the sets using each of the comparison operators. 
# Use print statements to the show the output of each.

# %%
# Part b -- combining the sets using each of the mathematical set operators,
# Use print statements to the show the output of each.

# %% [markdown]
# ## Reminder:
# *Before submitting:*
# * Run all cells
# * Save the file
# * Be sure your last name is part of the file name
